# %% [markdown]
# ## Generate the images of my game by pixray
#
# Github: https://github.com/pixray/pixray
#
# This notebook is modified from Minial Demo: https://github.com/pixray/pixray_notebooks/blob/master/pixray_minimal.ipynb

# %%
# gpu check
nvidia_output = !nvidia-smi --query-gpu=memory.total --format=noheader,nounits,csv
gpu_memory = int(nvidia_output[0])
if gpu_memory < 14000:
  print(f"--> GPU check: ONLY {gpu_memory} MiB available: WARNING, some things might not work <--")
else:
  print(f"GPU check: {gpu_memory} MiB available: this should be fine")

# install
print("Installing...")
from IPython.utils import io
with io.capture_output() as captured:
  # !rm -Rf pixray
  # !git clone --recursive https://github.com/pixray/pixray
  # !pip install -r pixray/requirements.txt
  # !pip uninstall -y tensorflow 
  # !git clone https://github.com/pixray/diffvg
  # %cd diffvg
  # !git submodule update --init --recursive
  # !python setup.py install
  # %cd ..
  # !pip freeze | grep torch

# remind restart runtime
import os
if not os.path.isfile("first_init_complete"):
  # put stuff in here that should only happen once
  # !mkdir -p models
  os.mknod("first_init_complete")
  print("Please choose Runtime -> Restart Runtime from the menu")
  print("(then continue below)")
else:
  print("Setup Complete! Good luck with your drawing")
# Out:
# GPU check: 15109 MiB available: this should be fine
# Installing...
# Please choose Runtime -> Restart Runtime from the menu
# (then continue below)

# %% [markdown]
# ## List of Prompts
#
# Locations and their prompts:
# * top_of_building_aug/top_of_building_jul: roof of a radio station building
# * lab: Inside a studio apartment with window:4 | microwave:2 | table and chair
# * time_machine: a time machine that looks like a satellite
# * stair_case: a staircase with stairs | dark and wet
# * storage: Storage room with boxes:2 | girl with red long hair wearing doctor's overall | middle-age man looking angry
# * floor_7: Staircase of floor 7
# * floor_8: Staircase of floor 8
#
# Items and their prompts:
# * Gashapon_machine: a gashapon machine with small toys
# * dollar: One dollar coin
# * phone: A phone playing news
# * lightsaber: A red lightsaber
# * knife: a silver knife
# * key: A bronze key
# * Stun_gun: A stun gun
# * metal_upa: A cute round metal toy with two eyes and two round ears
# * plastic_upa: A cute round green plastic toy with two eyes and two round ears
# * suzuha: An energetic girl in blue sports jacket with two brown braided ponytails

# %% [markdown]
# ## Run Pixray
#
# We aim to create two art styles: pixel and clipdraw

# %% [markdown]
# ### Location

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "roof of a radio station building"
drawer = "clipdraw"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-9=>2.482)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "roof of a radio station building"
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-17=>2.497)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "Inside a studio apartment with window:4 | microwave:2 | table and chair"
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-2=>17.18)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a time machine that looks like a satellite"
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-10=>2.637)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a staircase with stairs | dark and wet" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-31=>5.372)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "storage room with boxes:2 | girl with red long hair wearing doctor's overall | middle-age man looking angry" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-17=>10.18)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "staircase of floor 7" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-47=>2.472)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "staircase of floor 8" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 280, loss: 2.5, losses: 0.767, 0.084, 0.664, 0.0759, 0.639, 0.0782, -0.0133, 0.207 (-0=>2.503)

# %% [markdown]
# ### Item

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a gashapon machine with small toys" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-5=>2.268)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "one dollar coin" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-6=>2.665)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a phone playing news" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-14=>2.595)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a red lightsaber" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-28=>2.55)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a silver knife" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-10=>2.555)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a bronze key" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-40=>2.435)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a stun gun" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-6=>2.443)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "a cute round metal toy with two eyes and two round ears" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-13=>2.368)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "A cute round green plastic toy with two eyes and two round ears" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-18=>2.306)
# True

# %%
import sys
sys.path.append("pixray")
# Simple setup
import pixray

prompts = "An energetic girl in blue sports jacket with two brown braided ponytails" 
drawer = "pixel"

# these are good settings for pixeldraw
pixray.reset_settings()
pixray.add_settings(prompts=prompts)
pixray.add_settings(quality="better")
pixray.add_settings(drawer=drawer)
pixray.add_settings(custom_loss="saturation:0.5,smoothness:2")
pixray.add_settings(smoothness_type="log")
pixray.add_settings(display_clear=True)
settings = pixray.apply_settings()
pixray.do_init(settings)
pixray.do_run(settings)
# Out:
# iter: 300, finished (-10=>2.316)
# True
